# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load prepared data
prepared_data = pd.read_csv('data/processed/prepared_data.csv')

# %%
# Descriptive statistics
print(prepared_data.describe())
# Out:
#               FG3A         FG3M     FG3_PCT      FG_PCT           W  \
# count   270.000000   270.000000  270.000000  270.000000  270.000000
# mean   2402.418519   859.292593   35.708519   46.020000   39.811111
# std     457.429214   174.519477    1.654879    1.580471   11.910348
# min    1223.000000   406.000000   31.700000   40.800000   10.000000
# 25%    2111.500000   738.500000   34.600000   45.000000   32.000000
# 50%    2413.000000   867.000000   35.550000   46.100000   41.000000
# 75%    2679.750000   979.750000   36.875000   47.100000   48.000000
# max    3721.000000  1363.000000   41.600000   50.400000   73.000000
#
#                FGA          FGM          FTA          FTM          REB  \
# count   270.000000   270.000000   270.000000   270.000000   270.000000
# mean   6918.292593  3183.962963  1808.681481  1390.040741  3504.440741
# std     404.218066   220.332375   199.235720   151.917613   241.979419
# min    5586.000000  2425.000000  1258.000000   983.000000  2721.000000
# 25%    6716.750000  3055.500000  1672.000000  1284.500000  3367.500000
# 50%    7002.000000  3182.000000  1814.500000  1397.000000  3545.000000
# 75%    7176.000000  3337.000000  1934.750000  1484.000000  3658.500000
# max    7739.000000  3658.000000  2407.000000  1853.000000  4078.000000
#
#                AST          TOV         DREB         BLK         STL  \
# count   270.000000   270.000000   270.000000  270.000000  270.000000
# mean   1890.666667  1125.781481  2688.337037  383.829630  608.544444
# std     194.802521   108.071815   184.071228   61.430414   74.241367
# min    1456.000000   799.000000  2041.000000  195.000000  428.000000
# 25%    1752.250000  1060.000000  2575.500000  340.000000  557.500000
# 50%    1883.500000  1123.000000  2711.500000  379.500000  605.000000
# 75%    2005.750000  1196.000000  2806.250000  423.750000  656.000000
# max    2491.000000  1453.000000  3316.000000  612.000000  821.000000
#
#            2P_PCT
# count  270.000000
# mean    51.650594
# std      2.703010
# min     44.899285
# 25%     49.618191
# 50%     51.531301
# 75%     53.832454
# max     58.604986

# %%
# Distribution of wins
plt.figure(figsize=(10, 6))
sns.histplot(prepared_data['W'], bins=30, kde=True)
plt.title('Distribution of Wins')
plt.xlabel('Wins')
plt.ylabel('Frequency')
plt.savefig('visualizations/distribution_of_wins.png')
plt.show()
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Relationship between FG_PCT and Wins
plt.figure(figsize=(10, 6))
sns.scatterplot(x='FG_PCT', y='W', data=prepared_data)
plt.title('FG_PCT vs. Wins')
plt.xlabel('Field Goal Percentage')
plt.ylabel('Wins')
plt.savefig('visualizations/fg_pct_vs_wins.png')
plt.show()

# %%
# Correlation heatmap
plt.figure(figsize=(12, 8))
corr_matrix = prepared_data.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.savefig('visualizations/correlation_heatmap.png')
plt.show()
